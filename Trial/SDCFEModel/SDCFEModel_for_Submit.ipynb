# %% [markdown]
# ### 패키지 로딩

# %%
# Data Handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# To ignore warnings
import warnings 
warnings.filterwarnings('ignore')

# Seed 고정
import random
import os
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) 

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
import keras
from keras.utils import np_utils
from keras.models import Sequential,Model,load_model
from keras.layers import Dense,Dropout,BatchNormalization,Add,Input,Activation,Concatenate,Average
from keras.layers.merge import concatenate

# Scoring
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %% [markdown]
# ### 데이터 로딩

# %%
### Train Set Loading and split feautures and labels
TRAIN = pd.read_csv("C:/LG_Aimers/data/train.csv")
X = TRAIN.iloc[:,1:57]
y = TRAIN.iloc[:,57:]

### Seperate
PCB_press = X[["X_01","X_02","X_05","X_06"]]
material_weight = X[["X_03","X_10","X_11"]]
material_area = X[["X_07","X_08","X_09"]]
pad_loc = X[["X_14","X_15","X_16","X_17","X_18","X_13"]]
screw1_deep = X[["X_19","X_20","X_21","X_22"]]
connect_pin = X[["X_24","X_25","X_26","X_27","X_28","X_29","X_12"]]
screw2_deep = X[["X_30","X_31","X_32","X_33"]]
screw_rotate = X[["X_34","X_35","X_36","X_37"]]
housing = X[["X_38","X_39","X_40","X_46"]]
radom = X[["X_41","X_42","X_43","X_44","X_45"]]
RF = X[["X_49","X_50","X_51","X_52","X_53","X_54","X_55","X_56"]]

# %% [markdown]
# ### 모델 구축

# %%
### input 정의
PCB_press_input = keras.layers.Input(shape=(4,), name="PCB_press_input", dtype="float32")
material_weight_input = keras.layers.Input(shape=(3,), name="material_weight_input", dtype="float32")
material_area_input = keras.layers.Input(shape=(3,), name="material_area_input", dtype="float32")
pad_loc_input = keras.layers.Input(shape=(6,), name="pad_loc_input", dtype="float32")
screw1_deep_input = keras.layers.Input(shape=(4,), name="screw1_deep_input", dtype="float32")
connect_pin_input = keras.layers.Input(shape=(7,), name="connect_pin_input", dtype="float32")
screw2_deep_input = keras.layers.Input(shape=(4,), name="screw2_deep_input", dtype="float32")
screw_rotate_input = keras.layers.Input(shape=(4,), name="screw_rotate_input", dtype="float32")
housing_input = keras.layers.Input(shape=(4,), name="housing_input", dtype="float32")
radom_input = keras.layers.Input(shape=(5,), name="radom_input", dtype="float32")
RF_input = keras.layers.Input(shape=(8,), name="RF_input", dtype="float32")

# %%
# PCB_press
PCB_press_layer1 = keras.layers.Dense(256, activation="relu")(PCB_press_input)
PCB_press_layer2 = keras.layers.Dense(128, activation="relu")(PCB_press_layer1)
PCB_press_layer3 = keras.layers.Dense(256, activation="relu")(PCB_press_layer2)
PCB_press_layer4 = keras.layers.Dense(4, activation="relu")(PCB_press_layer3)

# material_weight
material_weight_layer1 = keras.layers.Dense(256, activation="relu")(material_weight_input)
material_weight_layer2 = keras.layers.Dense(128, activation="relu")(material_weight_layer1)
material_weight_layer3 = keras.layers.Dense(256, activation="relu")(material_weight_layer2)
material_weight_layer4 = keras.layers.Dense(3, activation="relu")(material_weight_layer3)

# material_area
material_area_layer1 = keras.layers.Dense(256, activation="relu")(material_area_input)
material_area_layer2 = keras.layers.Dense(128, activation="relu")(material_area_layer1)
material_area_layer3 = keras.layers.Dense(256, activation="relu")(material_area_layer2)
material_area_layer4 = keras.layers.Dense(3, activation="relu")(material_area_layer3)

# pad_loc
pad_loc_layer1 = keras.layers.Dense(256, activation="relu")(pad_loc_input)
pad_loc_layer2 = keras.layers.Dense(128, activation="relu")(pad_loc_layer1)
pad_loc_layer3 = keras.layers.Dense(256, activation="relu")(pad_loc_layer2)
pad_loc_layer4 = keras.layers.Dense(6, activation="relu")(pad_loc_layer3)

# screw1_deep
screw1_deep_layer1 = keras.layers.Dense(256, activation="relu")(screw1_deep_input)
screw1_deep_layer2 = keras.layers.Dense(128, activation="relu")(screw1_deep_layer1)
screw1_deep_layer3 = keras.layers.Dense(256, activation="relu")(screw1_deep_layer2) 
screw1_deep_layer4 = keras.layers.Dense(4, activation="relu")(screw1_deep_layer3)

# connect_pin
connect_pin_layer1 = keras.layers.Dense(256, activation="relu")(connect_pin_input)
connect_pin_layer2 = keras.layers.Dense(128, activation="relu")(connect_pin_layer1)
connect_pin_layer3 = keras.layers.Dense(256, activation="relu")(connect_pin_layer2)
connect_pin_layer4 = keras.layers.Dense(7, activation="relu")(connect_pin_layer3)

# screw2_deep
screw2_deep_layer1 = keras.layers.Dense(256, activation="relu")(screw2_deep_input)
screw2_deep_layer2 = keras.layers.Dense(128, activation="relu")(screw2_deep_layer1)
screw2_deep_layer3 = keras.layers.Dense(256, activation="relu")(screw2_deep_layer2)
screw2_deep_layer4 = keras.layers.Dense(4, activation="relu")(screw2_deep_layer3)

# screw_rotate
screw_rotate_layer1 = keras.layers.Dense(256, activation="relu")(screw_rotate_input)
screw_rotate_layer2 = keras.layers.Dense(128, activation="relu")(screw_rotate_layer1)
screw_rotate_layer3 = keras.layers.Dense(256, activation="relu")(screw_rotate_layer2)
screw_rotate_layer4 = keras.layers.Dense(4, activation="relu")(screw_rotate_layer3)

# housing
housing_layer1 = keras.layers.Dense(256, activation="relu")(housing_input)
housing_layer2 = keras.layers.Dense(128, activation="relu")(housing_layer1)
housing_layer3 = keras.layers.Dense(256, activation="relu")(housing_layer2)
housing_layer4 = keras.layers.Dense(4, activation="relu")(housing_layer3)

# radom
radom_layer1 = keras.layers.Dense(256, activation="relu")(radom_input)
radom_layer2 = keras.layers.Dense(128, activation="relu")(radom_layer1)
radom_layer3 = keras.layers.Dense(256, activation="relu")(radom_layer2)
radom_layer4 = keras.layers.Dense(5, activation="relu")(radom_layer3)

# RF
RF_layer1 = keras.layers.Dense(256, activation="relu")(RF_input)
RF_layer2 = keras.layers.Dense(128, activation="relu")(RF_layer1)
RF_layer3 = keras.layers.Dense(256, activation="relu")(RF_layer2)
RF_layer4 = keras.layers.Dense(8, activation="relu")(RF_layer3)

# concat
concat_layer = keras.layers.concatenate([PCB_press_layer4, material_weight_layer4, material_area_layer4, pad_loc_layer4, screw1_deep_layer4, connect_pin_layer4, screw2_deep_layer4, screw_rotate_layer4, housing_layer4, radom_layer4, RF_layer4])

# result
result_layer = keras.layers.Dense(14)(concat_layer)

# %%
### 딥러닝 모델 적합을 위한 numpy 형태로 변환
#### Features
PCB_press = np.array(PCB_press)
material_weight = np.array(material_weight)
material_area = np.array(material_area)
pad_loc = np.array(pad_loc)
screw1_deep = np.array(screw1_deep)
connect_pin = np.array(connect_pin)
screw2_deep = np.array(screw2_deep)
screw_rotate = np.array(screw_rotate)
housing = np.array(housing)
radom = np.array(radom)
RF = np.array(RF)
#### Target
y = np.array(y)

# %%
### Model Fitting 함수 정의
def fit_model(PCB_press_train,material_weight_train,material_area_train,pad_loc_train,screw1_deep_train,connect_pin_train,screw2_deep_train,screw_rotate_train,housing_train,radom_train,RF_train,PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val,y_train,y_val,i): 
    model = keras.Model(
        inputs=[PCB_press_input,material_weight_input,material_area_input,pad_loc_input,screw1_deep_input,connect_pin_input,screw2_deep_input,screw_rotate_input,housing_input,radom_input,RF_input], 
        outputs=result_layer)
    model.compile(loss='mse', optimizer='adam')

    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath = 'C:/LG_Aimers/Conv/model/'+'fold' + str(i) + '--.{val_loss:.3f}'+'.h5', 
        monitor='val_loss', 
        save_best_only=True)
    model.fit([PCB_press_train,material_weight_train,material_area_train,pad_loc_train,screw1_deep_train,connect_pin_train,screw2_deep_train,screw_rotate_train,housing_train,radom_train,RF_train], 
              y_train,
              batch_size=32,
              epochs=100, 
              validation_data=([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val], y_val), 
              callbacks=[early_stopping, checkpoint])
    return model

# %%
### 5-fold cross validation

kf=KFold(5,shuffle=True)
i=0
for train_index,val_index in kf.split(X):
  i+=1
  PCB_press_train,PCB_press_val=PCB_press[train_index],PCB_press[val_index]
  material_weight_train,material_weight_val=material_weight[train_index],material_weight[val_index]
  material_area_train,material_area_val=material_area[train_index],material_area[val_index]
  pad_loc_train,pad_loc_val=pad_loc[train_index],pad_loc[val_index]
  screw1_deep_train,screw1_deep_val=screw1_deep[train_index],screw1_deep[val_index]
  connect_pin_train,connect_pin_val=connect_pin[train_index],connect_pin[val_index]
  screw2_deep_train,screw2_deep_val=screw2_deep[train_index],screw2_deep[val_index]
  screw_rotate_train,screw_rotate_val=screw_rotate[train_index],screw_rotate[val_index]
  housing_train,housing_val=housing[train_index],housing[val_index]
  radom_train,radom_val=radom[train_index],radom[val_index]
  RF_train,RF_val=RF[train_index],RF[val_index]
  
  y_train,y_val=y[train_index],y[val_index]
  model=fit_model(PCB_press_train,material_weight_train,material_area_train,pad_loc_train,screw1_deep_train,connect_pin_train,screw2_deep_train,screw_rotate_train,housing_train,radom_train,RF_train,PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val,y_train,y_val,i)
  print('finish {} model'.format(i))
# Out:
# Epoch 1/100
# 991/991 [==============================] - 11s 10ms/step - loss: 33.8563 - val_loss: 1.5419
# Epoch 2/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.7130 - val_loss: 1.6716
# Epoch 3/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6588 - val_loss: 1.5332
# Epoch 4/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6389 - val_loss: 1.5239
# Epoch 5/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6376 - val_loss: 1.5319
# Epoch 6/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6183 - val_loss: 1.5048
# Epoch 7/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6147 - val_loss: 1.5525
# Epoch 8/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6134 - val_loss: 1.5536
# Epoch 9/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6046 - val_loss: 1.5446
# Epoch 10/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6002 - val_loss: 1.5242
# Epoch 11/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5904 - val_loss: 1.7345
# Epoch 12/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.6009 - val_loss: 1.5397
# Epoch 13/100
# 991/991 [==============================] - 9s 10ms/step - loss: 1.5924 - val_loss: 1.5072
# Epoch 14/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5908 - val_loss: 1.6121
# Epoch 15/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5955 - val_loss: 1.5343
# Epoch 16/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5883 - val_loss: 1.5461
# Epoch 17/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5917 - val_loss: 1.5240
# Epoch 18/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5831 - val_loss: 1.5095
# Epoch 19/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5825 - val_loss: 1.5174
# Epoch 20/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5816 - val_loss: 1.4940
# Epoch 21/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5789 - val_loss: 1.6255
# Epoch 22/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5837 - val_loss: 1.5238
# Epoch 23/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5872 - val_loss: 1.5752
# Epoch 24/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5793 - val_loss: 1.5087
# Epoch 25/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5804 - val_loss: 1.5143
# Epoch 26/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5757 - val_loss: 1.5325
# Epoch 27/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5790 - val_loss: 1.5491
# Epoch 28/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5773 - val_loss: 1.5051
# Epoch 29/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5796 - val_loss: 1.5025
# Epoch 30/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5778 - val_loss: 1.5125
# Epoch 31/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5757 - val_loss: 1.5388
# Epoch 32/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5746 - val_loss: 1.5397
# Epoch 33/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5807 - val_loss: 1.5080
# Epoch 34/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5744 - val_loss: 1.4906
# Epoch 35/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5725 - val_loss: 1.5652
# Epoch 36/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5792 - val_loss: 1.5587
# Epoch 37/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5750 - val_loss: 1.5142
# Epoch 38/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5713 - val_loss: 1.4929
# Epoch 39/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5734 - val_loss: 1.4997
# Epoch 40/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5755 - val_loss: 1.4890
# Epoch 41/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5725 - val_loss: 1.5119
# Epoch 42/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5768 - val_loss: 1.4980
# Epoch 43/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5714 - val_loss: 1.4964
# Epoch 44/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5726 - val_loss: 1.4984
# Epoch 45/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5724 - val_loss: 1.4946
# Epoch 46/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5717 - val_loss: 1.5018
# Epoch 47/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5711 - val_loss: 1.5015
# Epoch 48/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5734 - val_loss: 1.5094
# Epoch 49/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5686 - val_loss: 1.5188
# Epoch 50/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5712 - val_loss: 1.4888
# Epoch 51/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5718 - val_loss: 1.5454
# Epoch 52/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5700 - val_loss: 1.5092
# Epoch 53/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5700 - val_loss: 1.4959
# Epoch 54/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5704 - val_loss: 1.5130
# Epoch 55/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5675 - val_loss: 1.5487
# Epoch 56/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5685 - val_loss: 1.4970
# Epoch 57/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5689 - val_loss: 1.6049
# Epoch 58/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5694 - val_loss: 1.5441
# Epoch 59/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5672 - val_loss: 1.5822
# Epoch 60/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5662 - val_loss: 1.4991
# Epoch 61/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5694 - val_loss: 1.4987
# Epoch 62/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5686 - val_loss: 1.5064
# Epoch 63/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5665 - val_loss: 1.4930
# Epoch 64/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5704 - val_loss: 1.5230
# Epoch 65/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5669 - val_loss: 1.5247
# Epoch 66/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5668 - val_loss: 1.5013
# Epoch 67/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5686 - val_loss: 1.5083
# Epoch 68/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5684 - val_loss: 1.4869
# Epoch 69/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5663 - val_loss: 1.5088
# Epoch 70/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5693 - val_loss: 1.4880
# Epoch 71/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5660 - val_loss: 1.5124
# Epoch 72/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5686 - val_loss: 1.5024
# Epoch 73/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5647 - val_loss: 1.4896
# Epoch 74/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5656 - val_loss: 1.4896
# Epoch 75/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5682 - val_loss: 1.5498
# Epoch 76/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5666 - val_loss: 1.5297
# Epoch 77/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5652 - val_loss: 1.5043
# Epoch 78/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5662 - val_loss: 1.4959
# Epoch 79/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5652 - val_loss: 1.4933
# Epoch 80/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5654 - val_loss: 1.5576
# Epoch 81/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5657 - val_loss: 1.5328
# Epoch 82/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5665 - val_loss: 1.5141
# Epoch 83/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5632 - val_loss: 1.5518
# Epoch 84/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5658 - val_loss: 1.5213
# Epoch 85/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5655 - val_loss: 1.4925
# Epoch 86/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5632 - val_loss: 1.5017
# Epoch 87/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5644 - val_loss: 1.5053
# Epoch 88/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5652 - val_loss: 1.4989
# finish 1 model
# Epoch 1/100
# 991/991 [==============================] - 11s 9ms/step - loss: 1.5237 - val_loss: 1.6516
# Epoch 2/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5236 - val_loss: 1.6510
# Epoch 3/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5242 - val_loss: 1.6539
# Epoch 4/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5229 - val_loss: 1.6499
# Epoch 5/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5244 - val_loss: 1.6528
# Epoch 6/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5207 - val_loss: 1.6651
# Epoch 7/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5246 - val_loss: 1.6599
# Epoch 8/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5215 - val_loss: 1.6907
# Epoch 9/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5225 - val_loss: 1.6641
# Epoch 10/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5224 - val_loss: 1.6478
# Epoch 11/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5219 - val_loss: 1.6492
# Epoch 12/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5229 - val_loss: 1.6621
# Epoch 13/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5219 - val_loss: 1.6686
# Epoch 14/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5225 - val_loss: 1.6501
# Epoch 15/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5241 - val_loss: 1.7202
# Epoch 16/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5206 - val_loss: 1.6515
# Epoch 17/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5202 - val_loss: 1.6545
# Epoch 18/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5214 - val_loss: 1.6728
# Epoch 19/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5212 - val_loss: 1.6493
# Epoch 20/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5213 - val_loss: 1.6520
# Epoch 21/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5192 - val_loss: 1.6497
# Epoch 22/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5222 - val_loss: 1.6562
# Epoch 23/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5203 - val_loss: 1.6673
# Epoch 24/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5220 - val_loss: 1.6753
# Epoch 25/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5194 - val_loss: 1.6534
# Epoch 26/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5201 - val_loss: 1.6498
# Epoch 27/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5196 - val_loss: 1.6527
# Epoch 28/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5184 - val_loss: 1.6798
# Epoch 29/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5203 - val_loss: 1.6563
# Epoch 30/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5195 - val_loss: 1.6869
# finish 2 model
# Epoch 1/100
# 991/991 [==============================] - 11s 10ms/step - loss: 1.5550 - val_loss: 1.5233
# Epoch 2/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5550 - val_loss: 1.5209
# Epoch 3/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5542 - val_loss: 1.5292
# Epoch 4/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5531 - val_loss: 1.5124
# Epoch 5/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5546 - val_loss: 1.5275
# Epoch 6/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5549 - val_loss: 1.5117
# Epoch 7/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5538 - val_loss: 1.5611
# Epoch 8/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5551 - val_loss: 1.5208
# Epoch 9/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5534 - val_loss: 1.5106
# Epoch 10/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5536 - val_loss: 1.5100
# Epoch 11/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5522 - val_loss: 1.5137
# Epoch 12/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5525 - val_loss: 1.5155
# Epoch 13/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5518 - val_loss: 1.5176
# Epoch 14/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5514 - val_loss: 1.5114
# Epoch 15/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5518 - val_loss: 1.5198
# Epoch 16/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5513 - val_loss: 1.5125
# Epoch 17/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5527 - val_loss: 1.5133
# Epoch 18/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5525 - val_loss: 1.5165
# Epoch 19/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5511 - val_loss: 1.5156
# Epoch 20/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5508 - val_loss: 1.5104
# Epoch 21/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5509 - val_loss: 1.5197
# Epoch 22/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5533 - val_loss: 1.5099
# Epoch 23/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5500 - val_loss: 1.5135
# Epoch 24/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5517 - val_loss: 1.5161
# Epoch 25/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5512 - val_loss: 1.5210
# Epoch 26/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5517 - val_loss: 1.5112
# Epoch 27/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5509 - val_loss: 1.5218
# Epoch 28/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5517 - val_loss: 1.5100
# Epoch 29/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5519 - val_loss: 1.5138
# Epoch 30/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5511 - val_loss: 1.5181
# Epoch 31/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5512 - val_loss: 1.5190
# Epoch 32/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5516 - val_loss: 1.5155
# Epoch 33/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5512 - val_loss: 1.5131
# Epoch 34/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5507 - val_loss: 1.5171
# Epoch 35/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5509 - val_loss: 1.5329
# Epoch 36/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5520 - val_loss: 1.5114
# Epoch 37/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5499 - val_loss: 1.5114
# Epoch 38/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5512 - val_loss: 1.5213
# Epoch 39/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5510 - val_loss: 1.5123
# Epoch 40/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5508 - val_loss: 1.5102
# Epoch 41/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5504 - val_loss: 1.5108
# Epoch 42/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5512 - val_loss: 1.5128
# finish 3 model
# Epoch 1/100
# 991/991 [==============================] - 11s 10ms/step - loss: 1.5580 - val_loss: 1.4874
# Epoch 2/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5568 - val_loss: 1.5067
# Epoch 3/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5568 - val_loss: 1.4877
# Epoch 4/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5574 - val_loss: 1.4874
# Epoch 5/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5582 - val_loss: 1.4886
# Epoch 6/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5577 - val_loss: 1.4844
# Epoch 7/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5569 - val_loss: 1.4991
# Epoch 8/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5572 - val_loss: 1.4853
# Epoch 9/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5568 - val_loss: 1.4937
# Epoch 10/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5566 - val_loss: 1.4888
# Epoch 11/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5573 - val_loss: 1.4864
# Epoch 12/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5576 - val_loss: 1.5094
# Epoch 13/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5572 - val_loss: 1.4884
# Epoch 14/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5571 - val_loss: 1.4873
# Epoch 15/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5564 - val_loss: 1.4840
# Epoch 16/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5574 - val_loss: 1.4974
# Epoch 17/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5551 - val_loss: 1.4857
# Epoch 18/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5553 - val_loss: 1.4869
# Epoch 19/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5579 - val_loss: 1.4921
# Epoch 20/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5568 - val_loss: 1.4916
# Epoch 21/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5561 - val_loss: 1.4886
# Epoch 22/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5558 - val_loss: 1.4841
# Epoch 23/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5560 - val_loss: 1.4857
# Epoch 24/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5564 - val_loss: 1.5063
# Epoch 25/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5565 - val_loss: 1.4851
# Epoch 26/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5561 - val_loss: 1.4890
# Epoch 27/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5556 - val_loss: 1.4936
# Epoch 28/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5562 - val_loss: 1.4872
# Epoch 29/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5556 - val_loss: 1.4877
# Epoch 30/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5558 - val_loss: 1.4853
# Epoch 31/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5564 - val_loss: 1.4842
# Epoch 32/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5560 - val_loss: 1.4839
# Epoch 33/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5548 - val_loss: 1.4942
# Epoch 34/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5555 - val_loss: 1.4860
# Epoch 35/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5562 - val_loss: 1.4841
# Epoch 36/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5554 - val_loss: 1.4835
# Epoch 37/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5561 - val_loss: 1.4836
# Epoch 38/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5553 - val_loss: 1.4838
# Epoch 39/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5569 - val_loss: 1.4839
# Epoch 40/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5548 - val_loss: 1.4859
# Epoch 41/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5568 - val_loss: 1.4904
# Epoch 42/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5546 - val_loss: 1.4856
# Epoch 43/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5553 - val_loss: 1.4876
# Epoch 44/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5542 - val_loss: 1.5043
# Epoch 45/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5560 - val_loss: 1.4882
# Epoch 46/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5553 - val_loss: 1.4849
# Epoch 47/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5557 - val_loss: 1.4954
# Epoch 48/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5551 - val_loss: 1.4869
# Epoch 49/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5552 - val_loss: 1.4838
# Epoch 50/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5550 - val_loss: 1.4887
# Epoch 51/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5541 - val_loss: 1.4894
# Epoch 52/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5545 - val_loss: 1.4859
# Epoch 53/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5552 - val_loss: 1.5099
# Epoch 54/100
# 991/991 [==============================] - 10s 11ms/step - loss: 1.5565 - val_loss: 1.4877
# Epoch 55/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5547 - val_loss: 1.4845
# Epoch 56/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5554 - val_loss: 1.4872
# finish 4 model
# Epoch 1/100
# 991/991 [==============================] - 13s 11ms/step - loss: 1.5360 - val_loss: 1.5608
# Epoch 2/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5350 - val_loss: 1.5594
# Epoch 3/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5346 - val_loss: 1.5656
# Epoch 4/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5348 - val_loss: 1.5682
# Epoch 5/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5357 - val_loss: 1.5627
# Epoch 6/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5353 - val_loss: 1.5672
# Epoch 7/100
# 991/991 [==============================] - 11s 11ms/step - loss: 1.5367 - val_loss: 1.5779
# Epoch 8/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5364 - val_loss: 1.5657
# Epoch 9/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5346 - val_loss: 1.5570
# Epoch 10/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5354 - val_loss: 1.5598
# Epoch 11/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5346 - val_loss: 1.5570
# Epoch 12/100
# 991/991 [==============================] - 10s 10ms/step - loss: 1.5338 - val_loss: 1.5605
# Epoch 13/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5361 - val_loss: 1.5604
# Epoch 14/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5348 - val_loss: 1.5831
# Epoch 15/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5364 - val_loss: 1.5592
# Epoch 16/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5343 - val_loss: 1.5572
# Epoch 17/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5346 - val_loss: 1.5582
# Epoch 18/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5357 - val_loss: 1.5622
# Epoch 19/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5345 - val_loss: 1.5643
# Epoch 20/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5338 - val_loss: 1.5657
# Epoch 21/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5351 - val_loss: 1.5642
# Epoch 22/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5344 - val_loss: 1.5595
# Epoch 23/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5344 - val_loss: 1.5628
# Epoch 24/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5353 - val_loss: 1.5587
# Epoch 25/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5346 - val_loss: 1.5624
# Epoch 26/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5342 - val_loss: 1.5609
# Epoch 27/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5342 - val_loss: 1.5574
# Epoch 28/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5333 - val_loss: 1.5579
# Epoch 29/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5334 - val_loss: 1.5572
# Epoch 30/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5317 - val_loss: 1.5549
# Epoch 31/100
# 991/991 [==============================] - 9s 10ms/step - loss: 1.5327 - val_loss: 1.5584
# Epoch 32/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5328 - val_loss: 1.5550
# Epoch 33/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5314 - val_loss: 1.5592
# Epoch 34/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5311 - val_loss: 1.5582
# Epoch 35/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5335 - val_loss: 1.5593
# Epoch 36/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5336 - val_loss: 1.5555
# Epoch 37/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5303 - val_loss: 1.5520
# Epoch 38/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5294 - val_loss: 1.5485
# Epoch 39/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5336 - val_loss: 1.5721
# Epoch 40/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5333 - val_loss: 1.5715
# Epoch 41/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5343 - val_loss: 1.5517
# Epoch 42/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5304 - val_loss: 1.5590
# Epoch 43/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5314 - val_loss: 1.5549
# Epoch 44/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5245 - val_loss: 1.5621
# Epoch 45/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5246 - val_loss: 1.5482
# Epoch 46/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5334 - val_loss: 1.5620
# Epoch 47/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5307 - val_loss: 1.5600
# Epoch 48/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5329 - val_loss: 1.5535
# Epoch 49/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5294 - val_loss: 1.5546
# Epoch 50/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5282 - val_loss: 1.5547
# Epoch 51/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5280 - val_loss: 1.5640
# Epoch 52/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5284 - val_loss: 1.5685
# Epoch 53/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5306 - val_loss: 1.5638
# Epoch 54/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5341 - val_loss: 1.5601
# Epoch 55/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5282 - val_loss: 1.5516
# Epoch 56/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5311 - val_loss: 1.5466
# Epoch 57/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5274 - val_loss: 1.5452
# Epoch 58/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5247 - val_loss: 1.5443
# Epoch 59/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5266 - val_loss: 1.5707
# Epoch 60/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5317 - val_loss: 1.6666
# Epoch 61/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5338 - val_loss: 1.5560
# Epoch 62/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5335 - val_loss: 1.5568
# Epoch 63/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5304 - val_loss: 1.5445
# Epoch 64/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5244 - val_loss: 1.5485
# Epoch 65/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5302 - val_loss: 1.5472
# Epoch 66/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5271 - val_loss: 1.5454
# Epoch 67/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5234 - val_loss: 1.5596
# Epoch 68/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5292 - val_loss: 1.5644
# Epoch 69/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5320 - val_loss: 1.5622
# Epoch 70/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5269 - val_loss: 1.5447
# Epoch 71/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5269 - val_loss: 1.5585
# Epoch 72/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5325 - val_loss: 1.5531
# Epoch 73/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5274 - val_loss: 1.5526
# Epoch 74/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5280 - val_loss: 1.5598
# Epoch 75/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5297 - val_loss: 1.5552
# Epoch 76/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5271 - val_loss: 1.5596
# Epoch 77/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5329 - val_loss: 1.5573
# Epoch 78/100
# 991/991 [==============================] - 9s 9ms/step - loss: 1.5264 - val_loss: 1.5477
# finish 5 model

# %% [markdown]
# ### Stacking

# %%
### Stacking Model 불러오기

model1=load_model("C:/LG_Aimers/Conv/model/fold1--.1.487.h5")
print(model1.evaluate([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val))

model2=load_model("C:/LG_Aimers/Conv/model/fold2--.1.648.h5")
print(model2.evaluate([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val))

model3=load_model("C:/LG_Aimers/Conv/model/fold3--.1.510.h5")
print(model3.evaluate([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val))

model4=load_model("C:/LG_Aimers/Conv/model/fold4--.1.483.h5")
print(model4.evaluate([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val))

model5=load_model("C:/LG_Aimers/Conv/model/fold5--.1.544.h5")
print(model5.evaluate([PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val))
# Out:
# 248/248 [==============================] - 1s 5ms/step - loss: 1.5605
# 1.5605226755142212
# 248/248 [==============================] - 1s 4ms/step - loss: 1.5606
# 1.5605953931808472
# 248/248 [==============================] - 1s 4ms/step - loss: 1.5607
# 1.5607174634933472
# 248/248 [==============================] - 1s 4ms/step - loss: 1.5604
# 1.5603915452957153
# 248/248 [==============================] - 1s 4ms/step - loss: 1.5443
# 1.544338583946228

# %%
### Stacking Model 함수 정의
all_models=list([model1,model2,model3,model4,model5])
  
def define_stacked_model(members):
  # update all layers in all models to not be trainiable
  for i in range(len(members)):
    model=members[i]
    for layer in model.layers:
      layer.trainable=False
      # rename to avoid 'unique layer name' issue
      layer._name = 'ensemble_' + str(i+1) + '_' + layer.name
  
  # define multi-handed input
  ensemble_visible=[model.input for model in members]
  ensemble_outputs=[model.output for model in members]

  y=Average()(ensemble_outputs)

  model=Model(inputs=ensemble_visible,outputs=y,name='ensemble')

  keras.utils.plot_model(model,show_shapes=True,to_file='C:\LG_Aimers\XGB노가다\Y_03_결과\model_graph.jpg')

  model.compile(loss='mae',optimizer='adam')
  return model

def fit_stacked_model(model,trainX,valX,trainY,valY):
  x_train=[trainX for _ in range(len(model.input))]
  x_val=[valX for _ in range(len(model.input))]
  y_train=trainY
  y_val=valY

  es=keras.callbacks.EarlyStopping(monitor='val_loss',patience=20)
  checkpoint_filepath='/content/drive/MyDrive/lg aimers/ensemble_model.h5'
  cp=keras.callbacks.ModelCheckpoint(
      filepath=checkpoint_filepath,
      monitor='val_loss',
      save_best_only=True
  )
  model.fit(x_train,y_train,epochs=1,validation_data=(x_val,y_val),callbacks=[es,cp],batch_size=32)

def evaluate_stacked_model(model,inputX,y_val):
  x_val=[inputX for _ in range(len(model.input))]
  return model.evaluate(x_val,y_val)

def predict_stacked_model(model,inputX):
  x_test=[inputX for _ in range(len(model.input))]
  return model.predict(x_test)

# %%
### Stacking Model Define
n_members=5
members=all_models
stacked_model=define_stacked_model(members)

### Stacking Model Fitting
fit_stacked_model(stacked_model,[PCB_press_train,material_weight_train,material_area_train,pad_loc_train,screw1_deep_train,connect_pin_train,screw2_deep_train,screw_rotate_train,housing_train,radom_train,RF_train],[PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_train,y_val)

### Stacking Model Evaluation
evaluate_stacked_model(stacked_model,[PCB_press_val,material_weight_val,material_area_val,pad_loc_val,screw1_deep_val,connect_pin_val,screw2_deep_val,screw_rotate_val,housing_val,radom_val,RF_val],y_val)
# Out:
# 991/991 [==============================] - 21s 19ms/step - loss: 0.7104 - val_loss: 0.7145

# %%
# Out:
# 248/248 [==============================] - 4s 15ms/step - loss: 0.7145
# 0.714504063129425

# %% [markdown]
# ### Submission

# %%
### 실제 Test Data 불러오기
X_valid = pd.read_csv("C:/LG_Aimers/data/test.csv")

### Separate
PCB_press_valid = X_valid[["X_01","X_02","X_05","X_06"]]
material_weight_valid = X_valid[["X_03","X_10","X_11"]]
material_area_valid = X_valid[["X_07","X_08","X_09"]]
pad_loc_valid = X_valid[["X_14","X_15","X_16","X_17","X_18","X_13"]]
screw1_deep_valid = X_valid[["X_19","X_20","X_21","X_22"]]
connect_pin_valid = X_valid[["X_24","X_25","X_26","X_27","X_28","X_29","X_12"]]
screw2_deep_valid = X_valid[["X_30","X_31","X_32","X_33"]]
screw_rotate_valid = X_valid[["X_34","X_35","X_36","X_37"]]
housing_valid = X_valid[["X_38","X_39","X_40","X_46"]]
radom_valid = X_valid[["X_41","X_42","X_43","X_44","X_45"]]
RF_valid = X_valid[["X_49","X_50","X_51","X_52","X_53","X_54","X_55","X_56"]]

### Stacking
result=predict_stacked_model(stacked_model,[PCB_press_valid,material_weight_valid,material_area_valid,pad_loc_valid,screw1_deep_valid,connect_pin_valid,screw2_deep_valid,screw_rotate_valid,housing_valid,radom_valid,RF_valid])

### Submission
result = pd.DataFrame(result)
result.columns = ["Y_01","Y_02","Y_03","Y_04","Y_05","Y_06","Y_07","Y_08","Y_09","Y_10","Y_11","Y_12","Y_13","Y_14"]
result.to_csv("C:/LG_Aimers/Conv/submit.csv")
